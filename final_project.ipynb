# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilson10045/Dilson_Abreu/blob/main/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt

# %%
# !cat /content/Joint_table.csv

# %%
table_df=pd.read_csv("/content/Joint_table.csv")

# %%
table_df
# Out:
#       Product_Price   Category_Name  Order_Item_CardProd_Id  \
# 0        327.750000  Sporting Goods                    1360
# 1        327.750000  Sporting Goods                    1360
# 2        327.750000  Sporting Goods                    1360
# 3        327.750000  Sporting Goods                    1360
# 4        327.750000  Sporting Goods                    1360
# ...             ...             ...                     ...
# 4995      59.990002          Cleats                     365
# 4996      59.990002          Cleats                     365
# 4997      59.990002          Cleats                     365
# 4998      59.990002          Cleats                     365
# 4999      59.990002          Cleats                     365
#
#                           Product_Name Customer_Segment  Order_City  \
# 0                         Smart watch          Consumer      Bekasi
# 1                         Smart watch          Consumer     Bikaner
# ...

# %%
# table_df=table_df[['Customer_City','Order_Profit_Per_Order']].head(100)

table_df=table_df.groupby(['Customer_City'],as_index=False).sum()

# table_df=table_df.groupby(['Customer_City'],as_index=False).sum()
table_df
# Out:
# <ipython-input-500-6624ff4bff9f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   table_df=table_df.groupby(['Customer_City'],as_index=False).sum()
#     Customer_City  Product_Price  Order_Item_CardProd_Id  Order_Customer_Id  \
# 0       Aguadilla     259.980011                     806              12994
# 1         Alameda     149.980003                    1494              28099
# 2          Albany     695.490002                    3347              43182
# 3     Albuquerque    1112.560020                    6399              67842
# 4       Algonquin     149.980003                    1494              28510
# ..            ...            ...                     ...                ...
# 491       Yonkers      81.990002                     500                490
# ...

# %%
# table_df=(table_df.groupby('Customer_City')['Category_Name'].value_counts().unstack())
table_df=table_df.sort_values("Order_Profit_Per_Order", ascending=False).head(30)
table_df=table_df[["Customer_City","Order_Profit_Per_Order"]]
table_df
# Out:
#      Customer_City  Order_Profit_Per_Order
# 56          Caguas            45884.070282
# 253    Los Angeles             4172.670000
# 76         Chicago             2751.329962
# 90        Columbia             1174.720010
# 232      Lancaster             1172.359992
# 198       Honolulu             1149.599990
# 282          Miami             1113.569991
# 348        Phoenix              975.009993
# 21         Atlanta              946.699993
# 199        Houston              879.700000
# 251     Long Beach              831.839995
# 380      Riverside              829.769986
# 50           Bronx              814.159995
# 26     Bakersfield              755.070005
# 447           Troy              716.249981
# 429  Staten Island              712.789997
# 25           Azusa              711.840012
# 290  Mission Viejo              701.820003
# 456      Vega Baja              701.180005
# 23          Aurora              664.310003
# 449         Tucson              656.820008
# ...

# %%
# x=table_df["Customer_City"]
# y=table_df["Order_Profit_Per_Order"]

# %%
# plt.xlabel("Customer_City", fontsize=10)
# plt.ylabel("Order_Profit_Per_Order", fontsize=10)
# plt.figure(figsize=(15,10))
# plt.xticks(rotation=90, horizontalalignment="center")
# plt.bar(x,y)

table_df.plot.bar(x="Customer_City",y="Order_Profit_Per_Order",rot=90,figsize=(15,10));
ax=table_df.plot.barh(x="Customer_City",y="Order_Profit_Per_Order",rot=0,figsize=(15,10));
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '45884.1'),
#  Text(0, 0, '4172.67'),
#  Text(0, 0, '2751.33'),
#  Text(0, 0, '1174.72'),
#  Text(0, 0, '1172.36'),
#  Text(0, 0, '1149.6'),
#  Text(0, 0, '1113.57'),
#  Text(0, 0, '975.01'),
#  Text(0, 0, '946.7'),
#  Text(0, 0, '879.7'),
#  Text(0, 0, '831.84'),
#  Text(0, 0, '829.77'),
#  Text(0, 0, '814.16'),
#  Text(0, 0, '755.07'),
#  Text(0, 0, '716.25'),
#  Text(0, 0, '712.79'),
#  Text(0, 0, '711.84'),
#  Text(0, 0, '701.82'),
#  Text(0, 0, '701.18'),
#  Text(0, 0, '664.31'),
#  Text(0, 0, '656.82'),
#  Text(0, 0, '639.23'),
#  Text(0, 0, '637.94'),
#  Text(0, 0, '636.49'),
#  Text(0, 0, '624.46'),
#  Text(0, 0, '601.48'),
#  Text(0, 0, '597.16'),
#  Text(0, 0, '592.56'),
#  Text(0, 0, '576.88'),
#  Text(0, 0, '561.66')]
